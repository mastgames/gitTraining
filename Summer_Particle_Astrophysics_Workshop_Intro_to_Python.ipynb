# %% [markdown]
# <a href="https://colab.research.google.com/github/mastgames/gitTraining/blob/master/Summer_Particle_Astrophysics_Workshop_Intro_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro To Python
#
# Hannah Fronenberg (McGill University) - hannah.fronenberg@mail.mcgill.ca
#
# In this two-hour workshop we will cover python topics for beginners and also some tips and tricks that more experienced python users can implement into their coding practices. We will cover an introduction to python as a programming language, an overview of basic python objects and their built-in functions. We will also go over some of my favourite python libraries and modules for scientific programming. Time permitting, I will give a quick crash course in writing test code which is one way in which any programmer can level-up their coding game. This session will be highly interactive with coding demo’s, exercises, and exploration time built into the workshop’s schedule.
#
# ## Plan:
#
#
#
# 1.   What is python
# 2.   Intallation and environments
# 3.   Basic math and arithmetic
# 4.   Python objects and their functions
#
#
# > - Strings
# > - Floats
# > - Lists
# > - Arrays
# > - Dictionaries
# > - Classes
# > - Methods
#
# 5. Modules and Libraries
# 6. If time: test code

# %% [markdown]
# # What is python?
#
# Python is a programming language
# It is an interpreted language meaning it is not directly compiled into machine instructions. Python code is instead read and executed by some other program (ex. CPython, Jython, PyPy…)
#
# It is an object oriented language which menas that it organizes software design around data, or objects, rather than functions and logic.
#
# **Def object:** a data field that has unique attributes and behavior.

# %% [markdown]
# ## Follow along: Interpreter vs. Engine
#
# Interpreter vs Engine
# Python as an interpreter allows you to run python code on the command line just like bash. By typing the command:
#
# 				python3
#
# You can write and run python code in a python shell. ( I almost never use this except sometimes as a calculator)
# Python as an engine allows you to write and run python scripts in files with the file extension .py (this is what I use every day!). To do this make sure you are in a shell that has python running and run your code by typing:
#
# 		 python my_python_code.py

# %%
# pretend command line

# %%
# pretend command line

# %%
# pretend command line

# %%
# pretend command line

# %%
# pretend command line

# %%
# pretend command line

# %%
# pretend command line

# %% [markdown]
# # Installing Python and Creating Environemnts
#
# Python download: https://www.python.org/downloads/
#
# Download Anaconda: https://www.anaconda.com/
#
# Download Miniconda: https://docs.conda.io/en/latest/miniconda.html
#
# ### How to run Python
#
# 1. Interpreter: `python3`
#
#
#
#
#
# 2. Engine: `python my_python_code.py`
#
#
# ### Virtual Environments
# A virtual environment  a folder structure that allows you to run Python in a lightweight and isolated environment.
# Ex. You can have a different environment for each project with only the packages that you use for that specific project installed.
#
# Why would you want to use one exactly?
#
# - Avoid pollution: If you install packages to your operating system’s global Python, these packages will mix with the system-relevant packages (this has happened to me…)
#
# - Avoid system conflicts: If you update your operating system, then the packages you installed might get overwritten and lost (this has happened to me…)
#
# - Avoid dependency conflicts: You might want different versions of things for different codes and you can’t have multiple versions installed in the same place.
#
# - Keep track of dependencies for a project: If you want to make your code publicly available then you need to be able to tell people what packages your code uses.
#
# - No administrator lockouts during installation: Usually don’t need full system access to install things in an environment.
#
#
#
# Making a virtual environment with anaconda:
#
#     conda create --name myenv
#
# or with a specific python version
#
#     conda create -n myenv python=3.9
#
# To activate your environment (named myenv):
#
#     conda activate myenv
#
# To see all of the modules loaded in your environment:
#
#     conda list
#
# To deactive your environment:
#
#     conda deactivate
#
#
# Extra resources on conda environments: https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html

# %% [markdown]
# # Math in Python![Screen Shot 2022-05-06 at 2.57.30 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## Activity 1: Basic Math
#
# Defining a variable and call it whatever you like and feel free to play around with some of the functions above. If you want, your variable could be a complex number too!

# %%
# define your variable here

# %% [markdown]
# # Python Objects
#
#
# In Python, everthing is an object. Since everything is an object, you can pass anything to a function. This is not true of other languages. This is sometimes referred to as duck typing.
#
# Objects in python:
# - Strings
# - Floats
# - Lists
# - Arrays
# - Tuples
# - Functions (methods)
#
# There are also things called classes which are kind of like object constructors. They do take in arguments, like a function, but they themselves don’t produce any output per se.
#
# You can always check which type of thing you're dealing with by typing:
#
#     type('variable name')
#
# First up... strings and floats!... but first some notes about typing.

# %% [markdown]
# ## Typing in Python
#
# Python has **dynamic typing** as opposed to static typing. This means you do not need to specify what type of object something is. Python is smart. Python knows.
#
#
# Python has **strong typing** as opposed to weak typing. This means that if you want to change the type of object something is, you need to do so explicitly. Here, Python is not smart, it doesn’t know.
#
#
# Python style guide: https://peps.python.org/pep-0008/#id6

# %% [markdown]
# ## Strings and Floats
#
# A string is a single character or set of characters (or glyphs )
# They are denoted using “ ” or ‘ ‘ (it doesn’t matter which you use)
# They are:
# - Immutable
# - Homogeneous
# - Ordered
#
# A set of numbers that represent the actual numerical value of the characters, not just the glyph.They are denoted just using regular numbers. They are not integers.
#
# Both of these opjects come with lots of built-in operations. Let's check them out.
#
# Here is a concise list of string methods:https://www.w3schools.com/python/python_ref_string.asp

# %%
a = 'I love physics'
b = 3.5

# %%
#to see the operations you can do with these type the variable followed by a dot and a list of functions will pop up.

# %%
#Try adding a float and a string togehter...

# %%
#Try multipling a string by a float...

# %%
# Try converting a string to a float

c = '3'

# %% [markdown]
# ## Lists, Arrays, and Tuples
#
# These are all data structures that can used to store multiple strings/floats.
# These use indices to label their elements:
# ![Screen Shot 2022-05-06 at 3.29.08 PM.png](data:image/png;base64,...)
#
#
#
# ## Dictionaries
#
# Dictionaries also store data like lists/arrays/tuples but they store pairs  of data using a key:value structure.
# These are:
# - Unordered (the key is the index instead)
# - Heterogeneous
# - Mutable
#
#
#
# List Methods: https://www.w3schools.com/python/python_ref_list.asp
#
# Tuple Methods: https://www.w3schools.com/python/python_ref_tuple.asp
#
# Dictionary Methods: https://www.w3schools.com/python/python_ref_dictionary.asp

# %%
#Create a list and test out some of its functions

my_list = []

# %%
#Do the same for an array but first, we need to import numpy! 

import numpy as np 

my_arr = np.array([])

#try turning your list into an array...

# %%
# Do the same for a tuple

my_tuple = ()

# %%
#Create an about me dictionary! Here is mine but feel free to add more qualities and information about you 
about_me = {'my name': 'hannah', 'my age': 24, 'my school': 'McGill', 'my height (m)': 1.67}

# %%
about_me['my name']

# %% [markdown]
# # Flow control
#
# You can define a set of computations using loops.
#
# - If/elif/else : performs a computation if the condition is satisfied
#
# - While: repeats the computation until the condition is false
#
# - For: performs a computation for all the indices defined in the sequence
#
# With if and while statements, you quantify their conditions using these symbols:
# ![Screen Shot 2022-05-09 at 11.09.44 AM.png](data:image/png;base64,...)
#
# - Continue will skip to the next loop iteration.
#
# - Break will break out of the innermost loop.
#
# It is important to organize your code in a block. Blocks are typically indented with 4 spaces (1 tab in most setups).
# Most importantly, your indentation needs to be consistent across your whole script. You can have unlimited loops in loops and all you need to do is keep indenting. It is common to run into indentation errors! You can use your text editor to help you avoid these.

# %%
#FOR LOOP

x = np.arange(1,10,0.5) # define an array from 1-10 in steps of 0.5
print('array x:',x) #print that array

for i in range(len(x)): #go through all the indices of x and print out the value of x
  print(x[i])

# %%
# Measure some strings:
words = ['cat', 'window', 'defenestrate']
for w in words:
    print(w, len(w))

# %%
#IF LOOP
for i in range(len(x)): # go through all the possible x
  if x[i] > 5: # if x[i] is greater than 5 then...
    print("x[",i, "] is greater than 5") #...pring this statement
  elif x[i]< 5:
    print("x[",i, "] is less than 5")
  else: 
    print("x[",i,"] is 5!")

# %%
# WHILE STATEMENT 

n = 0

while n < 5:
  print('n is less than 5:',n)
  n += 1

#once the statement is false, the while loop breaks.

# %% [markdown]
# ## Activity 2: Practicing loops
# 1. Using a for loop compute the average of the numbers in the array n below
# 2. Using an if loop that you can use to check if a number is positive or negative. You can try writing a similar one that checks if a number is real or complex.
# 3. Use a while loop to comptue the sum of integers 1-10

# %%
# Find the average of n! (hint: you'll need to do one last step out of the loop)
n = np.linspace(0,2,19)
print(n)

# %%
# Checking if a number is positive or negative

# %%
# Summing integers 1-10

# %% [markdown]
# # Functions, Modules, and Libraries
#
# Functions allow us to nicely package tasks into something that is callable and interchangeable with different variables.
# They are defined like this:
#
#     def my_function(variables):
# 	      stuff to compute goes here
# 	      return result
#
# You can also save functions in .py files and import them into another script.
# Here are some MAGICAL lines for auto-importing into a jupyter notebook which I use all the time:
#
#     %load_ext autoreload
#     %autoreload 2
#
#
#
#
#
# My favourite libraries:
# - Numpy
# - Scipy
# - Matplotlib
# - Astropy
# - Sys
# - OS
#
# To import a libary you type:
#
#     import "libary name" as "namespace"
#     ex. import numpy as np

# %%
# Using Numpy to replace loops

# %% [markdown]
# ## Activity 3: Dot Product
#
# Write a function that computes the dot product of 2 vectors a and b .
#
# If you're working in a local jupyter notbook, save your function to a text file and import it as a module. Congratulations, you just made your first module!
#
# Compare the result of your module with the `np.dot` function

# %%
a = np.linspace() #pic your vector a
b = np.arange() #pic your vecotr b

# %%
# Out:
# vector a: [1.         1.33333333 1.66666667 2.         2.33333333 2.66666667
#  3.         3.33333333 3.66666667 4.        ]
# vector b: [ 2.          3.11111111  4.22222222  5.33333333  6.44444444  7.55555556
#   8.66666667  9.77777778 10.88888889 12.        ]
# my dot_product 205.55555555555554
# numpy 205.55555555555554

# %% [markdown]
# ## A Cool Example: Recursive Functions

# %%
def factorial(n):
  if n == 0:
    return 1
  return n*factorial(n-1)

# %%
#spice up your documentation

def factorial(n: int)->int:
  ''' returns the factorial of n'''

  if n == 0:
    return 1
  return n*factorial(n-1)

# %% [markdown]
# ## Activity 4: Plotting the Planck Distribution
#
# Plot the planck distrubution for T = 500 K.
#
# $B(\nu) = \frac{2 h ν^3}{c^2} \frac{1}{e^{h\nu/K_b T}-1} $
#
# Write exponents using:
#
#     np.exp("stuff in the exponent)

# %%
freq = np.linspace(0,3e14,50) # frequencies to plot in Hz

def planck_law(freq, temp):
  #write your function here
  return #your output

# %% [markdown]
# ## Activity 5: Looping with plots
#
# Plot the planck distrubution for several T all in the same plot and create a legend indicating the temperature of each blackbody curve.
#
# $B(\nu) = \frac{2 h ν^3}{c^2} \frac{1}{e^{h\nu/K_b T}-1} $

# %%
freq = np.linspace(0,3e14,50) # frequencies to plot in Hz
T = [500,700,1000,1200]

# %% [markdown]
# # Unit Tests
#
# Unit testing is a method that allows you to test individual units of code with program specific tests.
#
# In ”real” world coding, every program has to be tested. Getting in the habit of writing test code will help you level-up your programming and help you spend less time debugging code.
#
# In python the module that I use to do this is called nosetests and here are some basic examples of things to test:
#
# - Check that arrays are the right shape
# - If something has to be a particular value, check that
# - Check the data type of something
#
#
#
#
# Nosetest documentation: https://nose.readthedocs.io/en/latest/
#
# Another good resource: https://www.google.com/search?q=nosetests&oq=nosetests&aqs=chrome..69i57.1492j0j4&sourceid=chrome&ie=UTF-8

# %%
# Example code for unit tests

import unittest
import nose.tools as nt
import numpy as np


#command to run in terminal: nosetests thisfilename.py

#Types of things to test: 
    #1. Array shapes 
    #2. Specific values of things 
    #3. Correct data types



class test_tools():

    def setUp(self): #this will be run before the test functions 
        self.A = np.random.normal(0,0.5,size = (5,5)) 
        self.B = 1.2256*np.ones((7,5))
        self.C = np.diag(np.diag(np.ones((7,7)))) + np.diag(np.diag(0.5j*np.ones((7,7))))

        self.m = np.dot(self.C,self.B).dot(self.A)

        print('M:',self.m)
        print('C',self.C)

    def tearDown(self): #this will be run after the test functions 
        pass

    ## Check if array is the right shape
    def test_array_shape(self):

        nt.assert_equal(self.m.shape,(7,5))

   ## Test for a special value
   def test_value(self): 

        nt.assert_almost_equal(np.round(self.B[0,0],decimals = 2), 1.23, places = 2 )

    
    ## Test if it's a float 
    def test_if_float(self): 


        nt.assert_equal(np.dtype(self.A[0,1]),float)

    ## Check if it is complex
    def test_complex(self):

        nt.assert_equal(np.dtype(self.C[3,3]),complex)
